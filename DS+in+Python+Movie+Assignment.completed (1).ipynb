# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv(r"C:\Users\Kanika Berry\Downloads\Movie+Assignment+Data.csv") # Write your code for importing the csv file here
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies.shape
# Out:
# (5043, 28)

# %%
movies.ndim
# Out:
# 2

# %%
movies.size
# Out:
# 141204

# %%
movies.describe(include= ['object']) #for categorial values
# Out:
#         color     director_name    actor_2_name genres    actor_1_name  \
# count    5024              4939            5030   5043            5036
# unique      2              2398            3032    914            2097
# top     Color  Steven Spielberg  Morgan Freeman  Drama  Robert De Niro
# freq     4815                26              20    236              49
#
#        movie_title actor_3_name   plot_keywords  \
# count         5043         5020            4890
# unique        4917         3521            4760
# top       Ben-Hur    John Heard  based on novel
# freq             3            8               4
#
#                                           movie_imdb_link language country  \
# count                                                5043     5029    5038
# unique                                               4919       46      65
# top     http://www.imdb.com/title/tt0232500/?ref_=fn_t...  English     USA
# ...

# %%
movies.describe() #for numerical values
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
movies.nunique()
# Out:
# color                           2
# director_name                2398
# num_critic_for_reviews        528
# duration                      191
# director_facebook_likes       435
# actor_3_facebook_likes        906
# actor_2_name                 3032
# actor_1_facebook_likes        878
# gross                        4035
# genres                        914
# actor_1_name                 2097
# movie_title                  4917
# num_voted_users              4826
# cast_total_facebook_likes    3978
# actor_3_name                 3521
# facenumber_in_poster           19
# plot_keywords                4760
# movie_imdb_link              4919
# num_user_for_reviews          954
# language                       46
# country                        65
# content_rating                 18
# budget                        439
# title_year                     91
# actor_2_facebook_likes        917
# imdb_score                     78
# aspect_ratio                   22
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here     #Identify of null values column wise
null_counts = movies.isnull().sum()
print(null_counts)
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here #Identify of null values row wise
row_null_counts = movies.isnull().sum(axis=1)
print(row_null_counts)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
#Filtering of null values row wise
rows_with_nulls = movies[row_null_counts > 0]
print(rows_with_nulls)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4       NaN       Doug Walker                     NaN       NaN
# 55    Color        Peter Sohn                   298.0      93.0
# 84    Color      Roland Joffé                    10.0     109.0
# 98    Color      Hideaki Anno                     1.0     120.0
# 99    Color     Peter Jackson                   645.0     182.0
# ...     ...               ...                     ...       ...
# 5037  Color      Edward Burns                    14.0      95.0
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4                       131.0                     NaN          Rob Walker
# ...

# %%
# Write your code for column-wise null percentages here
null_percentages = (null_counts / len(movies)) * 100
print(null_percentages)
# Out:
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.416419
# language                      0.277613
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# title_year                    2.141582
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
#
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 

columns_to_drop = ['color', 'duration',
 'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name','actor_1_facebook_likes','actor_2_facebook_likes', 'cast_total_facebook_likes', 'facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords', 'actor_3_name'] 

df= movies.drop(columns=columns_to_drop)
print(df)
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
df.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
import pandas as pd

# Step 1: Calculate the percentage of Null values for each column
null_percentage = movies.isnull().mean() * 100

# Step 2: Identify columns with more than 5% Null values
columns_to_drop = null_percentage[null_percentage > 5].index

# Step 3: Drop rows with Null values in the identified columns
cleaned_df = movies.dropna(subset=columns_to_drop)

# Display the null percentages, columns to drop, and the shape of dataframes
print("Null Percentage for each column:\n", null_percentage)
print("Columns with more than 5% Null values:\n", columns_to_drop)
print(f"Original dataframe shape: {movies.shape}")
print(f"Cleaned dataframe shape: {cleaned_df.shape}")
# Out:
# Null Percentage for each column:
#  color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.416419
# language                      0.277613
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# ...

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Indices of rows to drop
rows_to_drop = [4]  # Replace with the actual indices you want to drop

# Dropping the rows
df= movies.drop(index=rows_to_drop)

# Display the DataFrame to verify the rows are dropped
print(df)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Filling NaN values in the 'language' column
movies['language'] = movies['language'].fillna('English')

# Display the DataFrame to verify NaN values are filled
print(movies)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
number_of_retained_rows = df.shape[0]
print(f'Number of retained rows: {number_of_retained_rows}')
# Out:
# Number of retained rows: 5043

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Define the conversion factor (example: converting meters to feet, 1 meter = 3.28084 feet)
conversion_factor = 0.684984

# Change the unit of the specified column (replace 'column_to_convert' with the actual column name)
movies['gross'] = movies['gross'] * conversion_factor


# Optionally, rename the column to reflect the new unit
df = movies.rename(columns={'gross': 'column_in_new_unit'})


# Print the DataFrame to verify changes
print(df)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes         gross                           genres  ...  \
# 0                  1000.0  5.209343e+08  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
movies['profit'] = movies['gross'] - movies['budget']

# %%
df_sorted = movies.sort_values(by='profit', ascending=False)

top10 = df_sorted.head(10)

print(top10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 3024  Color      George Lucas                   282.0     125.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# 0     Color     James Cameron                   723.0     178.0
# 26    Color     James Cameron                   315.0     194.0
# 509   Color      Roger Allers                   186.0      73.0
# 240   Color      George Lucas                   320.0     136.0
# 17    Color       Joss Whedon                   703.0     173.0
# 794   Color       Joss Whedon                   703.0     173.0
# 439   Color         Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 3024                      0.0                   504.0      Peter Cushing
# 29                      365.0                  1000.0         Judy Greer
# ...

# %%
top10 = df_sorted.head(10)

print(top10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 3024  Color      George Lucas                   282.0     125.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# 0     Color     James Cameron                   723.0     178.0
# 26    Color     James Cameron                   315.0     194.0
# 509   Color      Roger Allers                   186.0      73.0
# 240   Color      George Lucas                   320.0     136.0
# 17    Color       Joss Whedon                   703.0     173.0
# 794   Color       Joss Whedon                   703.0     173.0
# 439   Color         Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 3024                      0.0                   504.0      Peter Cushing
# 29                      365.0                  1000.0         Judy Greer
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# If dropping duplicates reduces the top 10 rows to less than 10, get more rows to fill up the top 10
while len(top10) < 10:
    next_rows = df_sorted.iloc[len(top10):len(top10)+10].drop_duplicates()
    top10 = pd.concat([top10, next_rows]).drop_duplicates().head(10)

# Display the top 10 profiting movies
print(top10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 3024  Color      George Lucas                   282.0     125.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# 0     Color     James Cameron                   723.0     178.0
# 26    Color     James Cameron                   315.0     194.0
# 509   Color      Roger Allers                   186.0      73.0
# 240   Color      George Lucas                   320.0     136.0
# 17    Color       Joss Whedon                   703.0     173.0
# 794   Color       Joss Whedon                   703.0     173.0
# 439   Color         Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 3024                      0.0                   504.0      Peter Cushing
# 29                      365.0                  1000.0         Judy Greer
# ...

# %%
# Write code for repeating subtask 2 here
movies['profit'] = movies['gross'] - movies['budget']
df_sorted = movies.sort_values(by='profit', ascending=False)

top10 = df_sorted.head(10)

print(top10)
top10 = df_sorted.head(10)

print(top10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 3024  Color      George Lucas                   282.0     125.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# 0     Color     James Cameron                   723.0     178.0
# 26    Color     James Cameron                   315.0     194.0
# 509   Color      Roger Allers                   186.0      73.0
# 240   Color      George Lucas                   320.0     136.0
# 17    Color       Joss Whedon                   703.0     173.0
# 794   Color       Joss Whedon                   703.0     173.0
# 439   Color         Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 3024                      0.0                   504.0      Peter Cushing
# 29                      365.0                  1000.0         Judy Greer
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
import pandas as pd

# Assuming you have a DataFrame 'df' with a column 'IMDb_score'

# Step 1: Sort the dataframe by 'IMDb_score' in descending order
df_sorted_by_imdb = df.sort_values(by='imdb_score', ascending=False)

# Step 2: Extract the top 250 movies
IMDb_Top_250 = df_sorted_by_imdb.head(250)

# Display the top 250 movies
print(IMDb_Top_250)
# Out:
#                  color         director_name  num_critic_for_reviews  \
# 2765             Color        John Blanchard                     NaN
# 1937             Color        Frank Darabont                   199.0
# 3466             Color  Francis Ford Coppola                   208.0
# 4409               NaN        John Stockwell                     2.0
# 2824             Color                   NaN                    53.0
# ...                ...                   ...                     ...
# 17               Color           Joss Whedon                   703.0
# 2174             Color         Steve McQueen                   597.0
# 715              Color         David Fincher                   568.0
# 4238   Black and White         William Wyler                    97.0
# 719              Color            Peter Weir                   213.0
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 2765      65.0                      0.0                   176.0
# ...

# %%
import pandas as pd

# Assuming 'IMDb_Top_250' is already created and contains a column 'language' or 'country'

# Example with 'language' column
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] != 'English']

# If 'language' column doesn't exist and you need to use 'country' column
# foreign_language_films = IMDb_Top_250[~IMDb_Top_250['country'].isin(['USA', 'UK', 'Australia', 'Canada'])]

# Display the top foreign language films
print(Top_Foreign_Lang_Film)
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
# Out:
#                  color                     director_name  \
# 4409               NaN                    John Stockwell
# 2824             Color                               NaN
# 3207             Color                               NaN
# 4498             Color                      Sergio Leone
# 4747   Black and White                    Akira Kurosawa
# 3579             Color                               NaN
# 4029             Color                Fernando Meirelles
# 2373             Color                    Hayao Miyazaki
# 3931             Color                        Ron Fricke
# 4921             Color                      Majid Majidi
# 3870             Color                        Raja Menon
# 4259             Color  Florian Henckel von Donnersmarck
# 4105             Color                    Chan-wook Park
# 2970             Color                 Wolfgang Petersen
# 4659             Color                    Asghar Farhadi
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
# Write your code for extracting the top 10 directors here
import pandas as pd

# Assuming you have a DataFrame 'df' with columns 'director_name' and 'imdb_score'

# Step 1: Group the dataframe by 'director_name'
grouped_directors = df.groupby('director_name')

# Step 2: Calculate the mean IMDb score for each director
director_mean_scores = grouped_directors['imdb_score'].mean()

# Step 3: Sort the directors based on the mean IMDb score in descending order
sorted_directors = director_mean_scores.sort_values(ascending=False)

# Step 4: Extract the top 10 directors with the highest mean IMDb scores
top10director = sorted_directors.head(10).reset_index()

# Rename the columns for clarity
top10director.columns = ['director_name', 'mean_imdb_score']

# Display the top 10 directors
print(top10director)
# Out:
#       director_name  mean_imdb_score
# 0    John Blanchard              9.5
# 1  Mitchell Altieri              8.7
# 2  Sadyk Sher-Niyaz              8.7
# 3         Cary Bell              8.7
# 4      Mike Mayhall              8.6
# 5   Charles Chaplin              8.6
# 6      Majid Majidi              8.5
# 7        Ron Fricke              8.5
# 8   Damien Chazelle              8.5
# 9        Raja Menon              8.5

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
movies[['genre_1', 'genre_2']] = movies['genres'].str.split('|', n=1, expand=True)
movies['genre_2'].fillna(movies['genre_1'], inplace=True)

# %%
movies_by_segment = movies.groupby(['genre_1', 'genre_2'])

# %%
# Step 3: Calculate the mean of the 'gross' values for each genre combination
genre_combinations_mean_gross = movies['gross'].mean()

# Step 4: Sort the genre combinations by the mean gross in descending order and extract the top 5
PopGenre = genre_combinations_mean_gross.sort_values(ascending=False).head(5).reset_index()

# Rename the columns for clarity
PopGenre.columns = ['genre_1', 'genre_2', 'mean_gross']

# Display the top 5 genre combinations
print(PopGenre)
# Write your code for getting the 5 most popular combo of genres here
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 5
#       2 genre_combinations_mean_gross = movies['gross'].mean()
#       4 # Step 4: Sort the genre combinations by the mean gross in descending order and extract the top 5
# ----> 5 PopGenre = genre_combinations_mean_gross.sort_values(ascending=False).head(5).reset_index()
#       7 # Rename the columns for clarity
#       8 PopGenre.columns = ['genre_1', 'genre_2', 'mean_gross']
#
# AttributeError: 'numpy.float64' object has no attribute 'sort_values'

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes 
Meryl_Streep = movies[movies['actor_1_name'] == 'Meryl Streep']

# %%
Leo_Caprio = movies[movies['actor_1_name'] == 'Leonardo DiCaprio']

# Include all movies in which Leo_Caprio is the lead

# %%
Brad_Pitt= movies[movies['actor_1_name'] == 'Brad Pitt'] # Include all movies in which Brad_Pitt is the lead

# %%
# Write your code for combining the three dataframes here
# Combine the dataframes
Combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt], ignore_index=True)

# Check the first few rows of the combined dataframe
print("Combined Dataframe:\n", Combined.head())
# Out:
# Combined Dataframe:
#     color   director_name  num_critic_for_reviews  duration  \
# 0  Color    Nancy Meyers                   187.0     120.0
# 1  Color   Curtis Hanson                    42.0     111.0
# 2  Color     Nora Ephron                   252.0     123.0
# 3  Color   David Frankel                   208.0     109.0
# 4  Color  Robert Redford                   227.0      92.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                    278.0                   963.0     Hunter Parrish
# 1                    161.0                   132.0    Glenn Morshower
# 2                      0.0                   923.0  Mary Lynn Rajskub
# 3                     64.0                   505.0      Anne Hathaway
# 4                      0.0                 10000.0         Tom Cruise
#
#    actor_1_facebook_likes         gross                           genres  ...  \
# 0                 11000.0  7.720007e+07             Comedy|Drama|Romance  ...
# ...

# %%
# Write your code for grouping the combined dataframe here
# Group by actor_1_name
grouped = Combined.groupby('actor_1_name')

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
# Calculate the mean of the relevant columns
mean_reviews = grouped[['num_critic_for_reviews', 'num_user_for_reviews']].mean()

# Display the mean reviews
print("Mean Reviews:\n", mean_reviews)
# Out:
# Mean Reviews:
#                     num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Brad Pitt                      231.944444            702.444444
# Leonardo DiCaprio              330.190476            914.476190
# Meryl Streep                   163.153846            257.307692

# %%
# Identify the actor with the highest mean reviews
critic_favorite = mean_reviews['num_critic_for_reviews'].idxmax()
audience_favorite = mean_reviews['num_user_for_reviews'].idxmax()

# Display the results
print(f"The critic-favorite actor is: {critic_favorite}")
print(f"The audience-favorite actor is: {audience_favorite}")
# Out:
# The critic-favorite actor is: Leonardo DiCaprio
# The audience-favorite actor is: Leonardo DiCaprio

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!
